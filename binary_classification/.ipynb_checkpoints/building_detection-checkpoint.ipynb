# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image
from tensorflow.python.keras import Model
from tensorflow.python.keras.layers import Conv2D, Input, MaxPooling2D, Conv2DTranspose, Concatenate, Dropout

# %%
#setting up the working directory
import os
os.chdir('../Binary Classification/')

# %%
train_x = sorted(glob.glob('train/*_image.tif'))
train_y = sorted(glob.glob('train/*_label.tif'))
test_x = sorted(glob.glob('test//*_image.tif'))
test_y = sorted(glob.glob('test/*_label.tif'))
print(len(train_x),len(test_x))
# Out:
# 70 30

# %%
#converting the training images in numpy array
train_xx = np.zeros((70,128,128,3))
train_yy = np.zeros((70,128,128,1))

for i, (img, mask) in enumerate(zip(train_x,train_y)):
    img = Image.open(img)
    np_img = np.array(img)
    train_xx[i] = np_img
    
    mask = Image.open(mask)
    np_mask = np.array(mask).reshape(128,128,1)
    train_yy[i] = np_mask

# %%
#converting the test images in numpy array
test_xx = np.zeros((30,128,128,3))
test_yy = np.zeros((30,128,128,1))

for i, (img, mask) in enumerate(zip(test_x,test_y)):
    img = Image.open(img)
    np_img = np.array(img)
    test_xx[i] = np_img
    
    mask = Image.open(mask)
    np_mask = np.array(mask).reshape(128,128,1)
    test_yy[i] = np_mask

# %%
#lets plot the sample input image and mask of the buildings
plt.imshow(train_xx[10,:,:,:].astype('uint8'))
plt.show()
plt.imshow(train_yy[10,:,:,0].astype('uint8'))
plt.show()

# %% [markdown]
# ## U-NET Model Development

# %%
x_in = Input(shape=(128, 128, 3))

'''Encoder'''
x_temp = Conv2D(32, (3, 3), activation='relu', padding='same')(x_in)
x_temp = Dropout(0.25)(x_temp)
x_skip1 = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = MaxPooling2D((2,2))(x_skip1)
x_temp = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = Dropout(0.25)(x_temp)
x_skip2 = Conv2D(32, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = MaxPooling2D((2,2))(x_skip2)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = Dropout(0.25)(x_temp)
x_skip3 = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = MaxPooling2D((2,2))(x_skip3)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2D(64, (3, 3), activation='relu', padding='same')(x_temp)

'''Decoder'''
x_temp = Conv2DTranspose(64, (3, 3), activation='relu',  padding='same')(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(64, (3, 3), strides=(2, 2), activation='relu',  padding='same')(x_temp)
x_temp = Concatenate()([x_temp, x_skip3])
x_temp = Conv2DTranspose(64, (3, 3), activation='relu',  padding='same')(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(64, (3, 3), strides=(2, 2), activation='relu',  padding='same')(x_temp)
x_temp = Concatenate()([x_temp, x_skip2])
x_temp = Conv2DTranspose(32, (3, 3), activation='relu',  padding='same')(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(32, (3, 3), strides=(2, 2), activation='relu',  padding='same')(x_temp)
x_temp = Concatenate()([x_temp, x_skip1])
x_temp = Conv2DTranspose(32, (3, 3), activation='relu',  padding='same')(x_temp)
x_temp = Dropout(0.5)(x_temp)
x_temp = Conv2DTranspose(32, (3, 3), activation='relu',  padding='same')(x_temp)

'''Use 1 by 1 Convolution to get desired output bands'''
x_temp = Conv2D(32, (1, 1), activation='relu', padding='same')(x_temp)
x_temp = Conv2D(32, (1, 1), activation='relu', padding='same')(x_temp)
x_out = Conv2D(1, (1, 1), activation='sigmoid', padding='same')(x_temp)
# use sigmoid activation here because output values are either 0 or 1

model = Model(inputs=x_in, outputs=x_out)

model.compile(loss='mean_squared_error', optimizer='adam')

model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 32) 896         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 32) 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 32) 9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 32)   9248        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 32)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 32)   9248        dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 64)   18496       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 64)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 64)   36928       dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   36928       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 16, 16, 64)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   36928       dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 16, 16, 64)   36928       conv2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 64)   0           conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 32, 32, 64)   36928       dropout_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 32, 32, 64)   73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 32, 64)   0           conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 64, 64, 64)   36928       dropout_13[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 96)   0           conv2d_transpose_11[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 64, 64, 32)   27680       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64, 64, 32)   0           conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 128, 128, 32) 9248        dropout_14[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 128, 128, 32) 18464       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128, 128, 32) 0           conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 128, 128, 32) 9248        dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 32) 1056        conv2d_transpose_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 32) 1056        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 1)  33          conv2d_20[0][0]
# ==================================================================================================
# Total params: 409,281
# Trainable params: 409,281
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#training the model
history = model.fit(train_xx, train_yy, validation_data=(test_xx, test_yy), epochs=100, batch_size=10, verbose=1)
# Out:
# Epoch 1/100
# 2/7 [=======>......................] - ETA: 0s - loss: 0.2037WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0054s vs `on_train_batch_end` time: 0.0907s). Check your callbacks.
# 7/7 [==============================] - ETA: 0s - loss: 0.1795WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_test_batch_end` time: 0.0150s). Check your callbacks.
# 7/7 [==============================] - 1s 131ms/step - loss: 0.1795 - val_loss: 0.1366
# Epoch 2/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.1493 - val_loss: 0.1284
# Epoch 3/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.1414 - val_loss: 0.1206
# Epoch 4/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.1369 - val_loss: 0.1180
# Epoch 5/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.1336 - val_loss: 0.1165
# Epoch 6/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.1313 - val_loss: 0.1173
# Epoch 7/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.1309 - val_loss: 0.1133
# Epoch 8/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.1285 - val_loss: 0.1136
# Epoch 9/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.1229 - val_loss: 0.1053
# Epoch 10/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.1228 - val_loss: 0.1063
# Epoch 11/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.1128 - val_loss: 0.0989
# Epoch 12/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.1183 - val_loss: 0.1077
# Epoch 13/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.1237 - val_loss: 0.1092
# Epoch 14/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.1214 - val_loss: 0.1101
# Epoch 15/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.1223 - val_loss: 0.1032
# Epoch 16/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.1109 - val_loss: 0.0949
# Epoch 17/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.1044 - val_loss: 0.0914
# Epoch 18/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0978 - val_loss: 0.0872
# Epoch 19/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0950 - val_loss: 0.0845
# Epoch 20/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0915 - val_loss: 0.0879
# Epoch 21/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0918 - val_loss: 0.0828
# Epoch 22/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0854 - val_loss: 0.0803
# Epoch 23/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0823 - val_loss: 0.0764
# Epoch 24/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0781 - val_loss: 0.0789
# Epoch 25/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0780 - val_loss: 0.0731
# Epoch 26/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0765 - val_loss: 0.0783
# Epoch 27/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0731 - val_loss: 0.0743
# Epoch 28/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0720 - val_loss: 0.0740
# Epoch 29/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0700 - val_loss: 0.0704
# Epoch 30/100
# 7/7 [==============================] - 1s 77ms/step - loss: 0.0695 - val_loss: 0.0687
# Epoch 31/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0680 - val_loss: 0.0686
# Epoch 32/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0659 - val_loss: 0.0672
# Epoch 33/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0646 - val_loss: 0.0691
# Epoch 34/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0645 - val_loss: 0.0654
# Epoch 35/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0653 - val_loss: 0.0634
# Epoch 36/100
# 7/7 [==============================] - ETA: 0s - loss: 0.064 - 1s 77ms/step - loss: 0.0649 - val_loss: 0.0669
# Epoch 37/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0635 - val_loss: 0.0651
# Epoch 38/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0618 - val_loss: 0.0648
# Epoch 39/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0596 - val_loss: 0.0640
# Epoch 40/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0579 - val_loss: 0.0622
# Epoch 41/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0581 - val_loss: 0.0629
# Epoch 42/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0565 - val_loss: 0.0610
# Epoch 43/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0562 - val_loss: 0.0638
# Epoch 44/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0576 - val_loss: 0.0609
# Epoch 45/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0553 - val_loss: 0.0594
# Epoch 46/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0555 - val_loss: 0.0592
# Epoch 47/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0539 - val_loss: 0.0591
# Epoch 48/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0532 - val_loss: 0.0593
# Epoch 49/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0528 - val_loss: 0.0593
# Epoch 50/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0528 - val_loss: 0.0595
# Epoch 51/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0529 - val_loss: 0.0587
# Epoch 52/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0526 - val_loss: 0.0595
# Epoch 53/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0517 - val_loss: 0.0591
# Epoch 54/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0511 - val_loss: 0.0595
# Epoch 55/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0502 - val_loss: 0.0594
# Epoch 56/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0502 - val_loss: 0.0576
# Epoch 57/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0499 - val_loss: 0.0574
# Epoch 58/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0490 - val_loss: 0.0575
# Epoch 59/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0490 - val_loss: 0.0568
# Epoch 60/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0484 - val_loss: 0.0575
# Epoch 61/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0479 - val_loss: 0.0576
# Epoch 62/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0478 - val_loss: 0.0573
# Epoch 63/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0471 - val_loss: 0.0564
# Epoch 64/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0475 - val_loss: 0.0567
# Epoch 65/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0471 - val_loss: 0.0574
# Epoch 66/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0477 - val_loss: 0.0586
# Epoch 67/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0465 - val_loss: 0.0575
# Epoch 68/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0467 - val_loss: 0.0571
# Epoch 69/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0461 - val_loss: 0.0548
# Epoch 70/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0460 - val_loss: 0.0568
# Epoch 71/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0460 - val_loss: 0.0560
# Epoch 72/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0461 - val_loss: 0.0561
# Epoch 73/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0460 - val_loss: 0.0588
# Epoch 74/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0463 - val_loss: 0.0564
# Epoch 75/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0456 - val_loss: 0.0551
# Epoch 76/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0452 - val_loss: 0.0565
# Epoch 77/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0451 - val_loss: 0.0580
# Epoch 78/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0448 - val_loss: 0.0556
# Epoch 79/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0436 - val_loss: 0.0550
# Epoch 80/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0442 - val_loss: 0.0545
# Epoch 81/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0438 - val_loss: 0.0553
# Epoch 82/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0437 - val_loss: 0.0564
# Epoch 83/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0435 - val_loss: 0.0567
# Epoch 84/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0430 - val_loss: 0.0541
# Epoch 85/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0426 - val_loss: 0.0557
# Epoch 86/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0424 - val_loss: 0.0557
# Epoch 87/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0427 - val_loss: 0.0547
# Epoch 88/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0424 - val_loss: 0.0540
# Epoch 89/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0420 - val_loss: 0.0534
# Epoch 90/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0419 - val_loss: 0.0541
# Epoch 91/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0416 - val_loss: 0.0533
# Epoch 92/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0419 - val_loss: 0.0546
# Epoch 93/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0415 - val_loss: 0.0554
# Epoch 94/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0425 - val_loss: 0.0576
# Epoch 95/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0426 - val_loss: 0.0573
# Epoch 96/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0422 - val_loss: 0.0557
# Epoch 97/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0421 - val_loss: 0.0533
# Epoch 98/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0408 - val_loss: 0.0541
# Epoch 99/100
# 7/7 [==============================] - 1s 79ms/step - loss: 0.0406 - val_loss: 0.0547
# Epoch 100/100
# 7/7 [==============================] - 1s 80ms/step - loss: 0.0402 - val_loss: 0.0542

# %%
# plot model loss over training and validation data
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#Prediction
threshold = 0.5

# prediction of the output
pred_test = model.predict(test_xx)
pred_test = (pred_test > threshold).astype(np.uint8)
print(pred_test.shape)

#let's comare random predicted and actial y values 
plt.imshow(pred_test[15, :, :, 0])
plt.show()
plt.imshow(test_yy[15,:,:,0])
plt.show()
# Out:
# (30, 128, 128, 1)

# %%
plt.imshow(test_xx[15,:,:,:].astype('uint8'))
plt.imshow(pred_test[15, :, :, 0], alpha=0.3)
#plt.imshow(test_yy[15,:,:,0], alpha=0.5)
